# %% [markdown]
# Exercise 1: Basic Usage Of SciPy
#
# Task: Import the SciPy library and explore its version.

# %%
import scipy

scipy.__version__
# Out:
# '1.15.3'

# %% [markdown]
# Exercise 2: Descriptive Statistics
#
# Task: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample Dataset:
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
import numpy as np
from scipy import stats

data = [12, 15, 13, 12, 18, 20, 22, 21]
avg = stats.tmean(data)
print(avg)
med = np.median(data)
print(med)
std_dev = stats.tstd(data)
print(std_dev)
# Out:
# 16.625
# 16.5
# 4.138236339311712

# %% [markdown]
# Exercise 3: Understanding Distributions
#
# Task: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.
# Code Example:
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm
#
# # complete your code here

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mu, sigma = 50, 10  # mean and standard deviation

# Create a normal distribution object
gaussian_dist = norm(loc=mu, scale=sigma)

# Generate x values around the mean
x_gaussian = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
pdf_gaussian = gaussian_dist.pdf(x_gaussian)

# Plot
plt.figure(figsize=(6, 4))
plt.plot(x_gaussian, pdf_gaussian, color='blue')
plt.title('Gaussian Distribution\n$\mu=50$, $\sigma=10$')
plt.xlabel('x')
plt.ylabel('PDF')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# <>:18: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/9m/2x6dfbbn0cq5m_g98d1wpw640000gn/T/ipykernel_39186/1192783606.py:18: SyntaxWarning: invalid escape sequence '\m'
#   plt.title('Gaussian Distribution\n$\mu=50$, $\sigma=10$')

# %% [markdown]
# Exercise 4: T-Test Application
#
# Task: Perform a T-test on two sets of randomly generated data.
# Code Example:
# data1 = np.random.normal(50, 10, 100)
# data2 = np.random.normal(60, 10, 100)
#
# # complete your code here

# %%
# Sample data
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

# Calculate means
mean_a = np.mean(data1)
mean_b = np.mean(data2)

# Calculate standard deviation
std_a = np.std(data1, ddof=1)
std_b = np.std(data2, ddof=1)

from scipy.stats import ttest_ind

# Perform T-test
t_stat, p_val = ttest_ind(data1, data2)

t_statistic = 2.5  # From the T-test
critical_value = 2.306  # From T-table or Python function

if abs(t_statistic) > critical_value:
  print("The difference is statistically significant.")
else:
  print("The difference is not statistically significant.")
# Out:
# The difference is statistically significant.

# %% [markdown]
# Exercise 5: Linear Regression Analysis
#
# Objective: Apply linear regression to a dataset and interpret the results.
#
# Task: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
# Dataset:
# house_sizes: [50, 70, 80, 100, 120] (in square meters)
# house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
# Questions:
# What is the slope and intercept of the regression line?
# Predict the price of a house that is 90 square meters.
# Interpret the meaning of the slope in the context of housing prices.

# %%
house_sizes = [50, 70, 80, 100, 120]
house_prices = [150000, 200000, 210000, 250000, 280000]

# Performing linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(house_sizes, house_prices)

# The slope and intercept of the regression line
print("Slope:", slope)
print("Intercept:", intercept)

#Predict the price of a house that is 90 square meters.
price_at_90 = 90 * slope + intercept
print(price_at_90)

#Interpret the meaning of the slope in the context of housing prices: How much the house price increase for a 1 square meter increase in house size.
# Out:
# Slope: 1828.7671232876712
# Intercept: 64383.56164383562
# 228972.60273972602

# %% [markdown]
# Exercise 6: Understanding ANOVA
#
# Objective: Test understanding of ANOVA and its application.
#
# Task: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
# Dataset:
# fertilizer_1: [5, 6, 7, 6, 5]
# fertilizer_2: [7, 8, 7, 9, 8]
# fertilizer_3: [4, 5, 4, 3, 4]
# Questions:
# Perform an ANOVA test on the given data. What are the F-value and P-value?
# Based on the P-value, do the fertilizers have significantly different effects on plant growth?
# Explain what would happen if the P-value were greater than 0.05.

# %%
from scipy.stats import t

fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

# Performing one-way ANOVA
f_value, p_value = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print("F-value:", f_value)
print("P-value:", p_value)

#Based on the P-value, do the fertilizers have significantly different effects on plant growth?
degree_of_freedom = 12
alpha = 0.05
#This result provides some evidence against the null hypothesis. It suggests there might be an effect, but more evidence is needed.

#Explain what would happen if the P-value were greater than 0.05.
#If the p-value were greater than 0.05, I would fail to reject the null hypothesis,
#meaning there is not enough evidence to conclude that the fertilizers have a significant effect on plant growth.
# Out:
# F-value: 28.52631578947368
# P-value: 2.754267209804844e-05

# %% [markdown]
# Exercise 7: Probability Distributions (Optional)
#
# Work with a binomial distribution: calculate probabilities for different numbers of successes.
# Example: Calculating the probability of getting exactly 5 heads in 10 coin flips.

# %%
from scipy.stats import binom

n = 10      # total flips
k = 5       # desired number of heads
p = 0.5     # probability of heads

# Probability of exactly k successes (heads)
prob = binom.pmf(k, n, p)

print(f"Probability of exactly {k} heads in {n} flips: {prob:.4f}")
# Out:
# Probability of exactly 5 heads in 10 flips: 0.2461

# %% [markdown]
# Exercise 8: Correlation Coefficients (Optional)
#
# Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.
# Example in code: data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

# %%
import pandas as pd

data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

from scipy.stats import pearsonr

# Calculate Pearson Correlation between Monthly Income and Online Purchase Frequency
corr, _ = pearsonr(data['age'], data['income'])
print(f'Pearson Correlation Coefficient: {corr:.2f}')

from scipy.stats import spearmanr

# Calculate Spearman Rank Correlation between Age and Hours Spent on Social Media
corr, _ = spearmanr(data['age'], data['income'])
print(f'Spearman Rank Correlation: {corr:.2f}')
# Out:
# Pearson Correlation Coefficient: 1.00
# Spearman Rank Correlation: 1.00
